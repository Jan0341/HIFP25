# %%
# !pip install dask_ml
# Out:
# Requirement already satisfied: dask_ml in /home/ec2-user/.venv/lib/python3.9/site-packages (2024.4.4)
# Requirement already satisfied: dask-glm>=0.2.0 in /home/ec2-user/.venv/lib/python3.9/site-packages (from dask_ml) (0.3.2)
# Requirement already satisfied: dask>=2.4.0 in /home/ec2-user/.venv/lib/python3.9/site-packages (from dask[array,dataframe]>=2.4.0->dask_ml) (2024.8.0)
# Requirement already satisfied: distributed>=2.4.0 in /home/ec2-user/.venv/lib/python3.9/site-packages (from dask_ml) (2024.8.0)
# Requirement already satisfied: multipledispatch>=0.4.9 in /home/ec2-user/.venv/lib/python3.9/site-packages (from dask_ml) (1.0.0)
# Requirement already satisfied: numba>=0.51.0 in /home/ec2-user/.venv/lib/python3.9/site-packages (from dask_ml) (0.60.0)
# Requirement already satisfied: numpy>=1.20.0 in /home/ec2-user/.venv/lib/python3.9/site-packages (from dask_ml) (2.0.2)
# Requirement already satisfied: packaging in /home/ec2-user/.venv/lib/python3.9/site-packages (from dask_ml) (25.0)
# Requirement already satisfied: pandas>=0.24.2 in /home/ec2-user/.venv/lib/python3.9/site-packages (from dask_ml) (2.2.3)
# Requirement already satisfied: scikit-learn>=1.2.0 in /home/ec2-user/.venv/lib/python3.9/site-packages (from dask_ml) (1.6.1)
# Requirement already satisfied: scipy in /home/ec2-user/.venv/lib/python3.9/site-packages (from dask_ml) (1.13.1)
# Requirement already satisfied: click>=8.1 in /home/ec2-user/.venv/lib/python3.9/site-packages (from dask>=2.4.0->dask[array,dataframe]>=2.4.0->dask_ml) (8.1.8)
# Requirement already satisfied: cloudpickle>=1.5.0 in /home/ec2-user/.venv/lib/python3.9/site-packages (from dask>=2.4.0->dask[array,dataframe]>=2.4.0->dask_ml) (3.1.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /home/ec2-user/.venv/lib/python3.9/site-packages (from dask>=2.4.0->dask[array,dataframe]>=2.4.0->dask_ml) (2025.5.1)
# Requirement already satisfied: partd>=1.4.0 in /home/ec2-user/.venv/lib/python3.9/site-packages (from dask>=2.4.0->dask[array,dataframe]>=2.4.0->dask_ml) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /home/ec2-user/.venv/lib/python3.9/site-packages (from dask>=2.4.0->dask[array,dataframe]>=2.4.0->dask_ml) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in /home/ec2-user/.venv/lib/python3.9/site-packages (from dask>=2.4.0->dask[array,dataframe]>=2.4.0->dask_ml) (1.0.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /home/ec2-user/.venv/lib/python3.9/site-packages (from dask>=2.4.0->dask[array,dataframe]>=2.4.0->dask_ml) (8.7.0)
# Requirement already satisfied: sparse>=0.7.0 in /home/ec2-user/.venv/lib/python3.9/site-packages (from dask-glm>=0.2.0->dask_ml) (0.15.5)
# Requirement already satisfied: dask-expr<1.2,>=1.1 in /home/ec2-user/.venv/lib/python3.9/site-packages (from dask[array,dataframe]>=2.4.0->dask_ml) (1.1.10)
# Requirement already satisfied: pyarrow>=7.0.0 in /home/ec2-user/.venv/lib/python3.9/site-packages (from dask-expr<1.2,>=1.1->dask[array,dataframe]>=2.4.0->dask_ml) (20.0.0)
# Requirement already satisfied: jinja2>=2.10.3 in /home/ec2-user/.venv/lib/python3.9/site-packages (from distributed>=2.4.0->dask_ml) (3.1.6)
# Requirement already satisfied: locket>=1.0.0 in /home/ec2-user/.venv/lib/python3.9/site-packages (from distributed>=2.4.0->dask_ml) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.0 in /home/ec2-user/.venv/lib/python3.9/site-packages (from distributed>=2.4.0->dask_ml) (1.1.0)
# Requirement already satisfied: psutil>=5.7.2 in /home/ec2-user/.venv/lib/python3.9/site-packages (from distributed>=2.4.0->dask_ml) (7.0.0)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /home/ec2-user/.venv/lib/python3.9/site-packages (from distributed>=2.4.0->dask_ml) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /home/ec2-user/.venv/lib/python3.9/site-packages (from distributed>=2.4.0->dask_ml) (3.1.0)
# Requirement already satisfied: tornado>=6.0.4 in /home/ec2-user/.venv/lib/python3.9/site-packages (from distributed>=2.4.0->dask_ml) (6.5.1)
# Requirement already satisfied: urllib3>=1.24.3 in /home/ec2-user/.venv/lib/python3.9/site-packages (from distributed>=2.4.0->dask_ml) (1.26.20)
# Requirement already satisfied: zict>=3.0.0 in /home/ec2-user/.venv/lib/python3.9/site-packages (from distributed>=2.4.0->dask_ml) (3.0.0)
# Requirement already satisfied: zipp>=3.20 in /home/ec2-user/.venv/lib/python3.9/site-packages (from importlib-metadata>=4.13.0->dask>=2.4.0->dask[array,dataframe]>=2.4.0->dask_ml) (3.22.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ec2-user/.venv/lib/python3.9/site-packages (from jinja2>=2.10.3->distributed>=2.4.0->dask_ml) (3.0.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /home/ec2-user/.venv/lib/python3.9/site-packages (from numba>=0.51.0->dask_ml) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/ec2-user/.venv/lib/python3.9/site-packages (from pandas>=0.24.2->dask_ml) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/ec2-user/.venv/lib/python3.9/site-packages (from pandas>=0.24.2->dask_ml) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/ec2-user/.venv/lib/python3.9/site-packages (from pandas>=0.24.2->dask_ml) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/.venv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas>=0.24.2->dask_ml) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in /home/ec2-user/.venv/lib/python3.9/site-packages (from scikit-learn>=1.2.0->dask_ml) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/ec2-user/.venv/lib/python3.9/site-packages (from scikit-learn>=1.2.0->dask_ml) (3.6.0)

# %%
import dask.dataframe as dd
from dask.diagnostics import ProgressBar
pbar = ProgressBar(); pbar.register()

# %% [markdown]
# 0. Initial Setup: Explore & Persist
# Before transformations, persist the DataFrame:

# %%
dic = {
    'Provider': 'category',
    'Race_mode': 'category',
    'State_mode': 'category',
    'County_mode': 'category',
    'PotentialFraud': 'category',
    'Bene_Age_Sum': 'float64',
    'TotalClaims': 'float64',
    'AttendingPhysician_TotalClaims': 'float64',
    'Prv_Physician_Count': 'float64',
    'Provider_Insurance_Claim_Reimbursement_Amt': 'float64',
    'Provider_Total_Patients': 'float64',
    'Provider_Total_ChronicCond_Alzheimer_Patients': 'float64',
    'Provider_Total_ChronicCond_Heartfailure_Patients': 'float64',
    'Provider_Total_ChronicCond_KidneyDisease_Patients': 'float64',
    'Provider_Total_ChronicCond_Cancer_Patients': 'float64',
    'Provider_Total_ChronicCond_ObstrPulmonary_Patients': 'float64',
    'Provider_Total_ChronicCond_Depression_Patients': 'float64',
    'Provider_Total_ChronicCond_Diabetes_Patients': 'float64',
    'Provider_Total_ChronicCond_IschemicHeart_Patients': 'float64',
    'Provider_Total_ChronicCond_Osteoporasis_Patients': 'float64',
    'Provider_Total_ChronicCond_rheumatoidarthritis_Patients': 'float64',
    'Provider_Total_ChronicCond_stroke_Patients': 'float64',
    'ClmAdmitDiagnosisCode_Count': 'float64',
    'ClmDiagnosisCode_1_Count': 'float64',
    'ClmDiagnosisCode_2_Count': 'float64',
    'ClmDiagnosisCode_3_Count': 'float64',
    'ClmAdmitDiagnosisCode_Most_Frequent': 'category',
    'ClmDiagnosisCode_1_Most_Frequent': 'category',
    'ClmDiagnosisCode_2_Most_Frequent': 'category',
    'ClmDiagnosisCode_3_Most_Frequent': 'category',
    'AttendingPhysician_Most_Frequent': 'category',
    'OperatingPhysician_Most_Frequent': 'category',
    'OtherPhysician_Most_Frequent': 'category',
    'Avg_allocated_Amount_Per_Provider': 'float64',
    'Avg_Deductible_Amt_Paid_Per_Provider': 'float64',
    'Avg_InscClaimAmtReimbursed_Per_Provider': 'float64',
    'perc_allocated_used': 'float64',
    'prv_avg_claims': 'float64',
    'prv_avg_claim_cost_indicator': 'float64',
    'prv_avg_claims_indicator': 'float64'
}

# %%
merged_path = "s3://medicare-fraud-data-25-05-2025/merged_ready/train/*.csv"
df_train = dd.read_csv(merged_path,dtype=dic, assume_missing=True)

# %%
df_train = df_train.persist()
# Out:
# [########################################] | 100% Completed | 420.06 ms

# %%
dtypes_long = df_train.dtypes.reset_index()
dtypes_long.columns = ['column_name', 'dtype']

# Ganze Tabelle anzeigen, unabhängig von Länge
print(dtypes_long.to_string(index=False))
# Out:
#                                             column_name    dtype
#                                                Provider category
#                                       ClaimDuration_sum  float64
#                                      ClaimDuration_mean  float64
#                                       ClaimDuration_std  float64
#                                       ClaimDuration_max  float64
#                                       ClaimDuration_min  float64
#                                    HospitalDuration_sum  float64
#                                   HospitalDuration_mean  float64
#                                    HospitalDuration_std  float64
#                                    HospitalDuration_max  float64
#                                    HospitalDuration_min  float64
#                                   DeductibleAmtPaid_sum  float64
#                                  DeductibleAmtPaid_mean  float64
#                                   DeductibleAmtPaid_std  float64
#                                   DeductibleAmtPaid_max  float64
#                                   DeductibleAmtPaid_min  float64
#                           IPAnnualReimbursementAmt_mean  float64
#                            IPAnnualReimbursementAmt_max  float64
#                              IPAnnualDeductibleAmt_mean  float64
#                               IPAnnualDeductibleAmt_max  float64
#                           OPAnnualReimbursementAmt_mean  float64
#                            OPAnnualReimbursementAmt_max  float64
#                              OPAnnualDeductibleAmt_mean  float64
#                               OPAnnualDeductibleAmt_max  float64
#                               ChronicCond_Alzheimer_sum  float64
#                              ChronicCond_Alzheimer_mean  float64
#                            ChronicCond_Heartfailure_sum  float64
#                           ChronicCond_Heartfailure_mean  float64
#                           ChronicCond_KidneyDisease_sum  float64
#                          ChronicCond_KidneyDisease_mean  float64
#                                  ChronicCond_Cancer_sum  float64
#                                 ChronicCond_Cancer_mean  float64
#                          ChronicCond_ObstrPulmonary_sum  float64
#                         ChronicCond_ObstrPulmonary_mean  float64
#                              ChronicCond_Depression_sum  float64
#                             ChronicCond_Depression_mean  float64
#                                ChronicCond_Diabetes_sum  float64
#                               ChronicCond_Diabetes_mean  float64
#                           ChronicCond_IschemicHeart_sum  float64
#                          ChronicCond_IschemicHeart_mean  float64
#                            ChronicCond_Osteoporasis_sum  float64
#                           ChronicCond_Osteoporasis_mean  float64
#                     ChronicCond_rheumatoidarthritis_sum  float64
#                    ChronicCond_rheumatoidarthritis_mean  float64
#                                  ChronicCond_stroke_sum  float64
#                                 ChronicCond_stroke_mean  float64
#                                           ClaimID_count  float64
#                              ClmDiagnosisCode_1_nunique  float64
#                              ClmDiagnosisCode_2_nunique  float64
#                              ClmDiagnosisCode_3_nunique  float64
#                              ClmProcedureCode_1_nunique  float64
#                              ClmProcedureCode_2_nunique  float64
#                              AttendingPhysician_nunique  float64
#                              OperatingPhysician_nunique  float64
#                                  OtherPhysician_nunique  float64
#                                          Gender_nunique  float64
#                                               Race_mode category
#                                              State_mode category
#                                             County_mode category
#                                          PotentialFraud category
#                                            Bene_Age_Sum  float64
#                                             TotalClaims  float64
#                          AttendingPhysician_TotalClaims  float64
#                                     Prv_Physician_Count  float64
#              Provider_Insurance_Claim_Reimbursement_Amt  float64
#                                 Provider_Total_Patients  float64
#           Provider_Total_ChronicCond_Alzheimer_Patients  float64
#        Provider_Total_ChronicCond_Heartfailure_Patients  float64
#       Provider_Total_ChronicCond_KidneyDisease_Patients  float64
#              Provider_Total_ChronicCond_Cancer_Patients  float64
#      Provider_Total_ChronicCond_ObstrPulmonary_Patients  float64
#          Provider_Total_ChronicCond_Depression_Patients  float64
#            Provider_Total_ChronicCond_Diabetes_Patients  float64
#       Provider_Total_ChronicCond_IschemicHeart_Patients  float64
#        Provider_Total_ChronicCond_Osteoporasis_Patients  float64
# Provider_Total_ChronicCond_rheumatoidarthritis_Patients  float64
#              Provider_Total_ChronicCond_stroke_Patients  float64
#                             ClmAdmitDiagnosisCode_Count  float64
#                                ClmDiagnosisCode_1_Count  float64
#                                ClmDiagnosisCode_2_Count  float64
#                                ClmDiagnosisCode_3_Count  float64
#                     ClmAdmitDiagnosisCode_Most_Frequent category
#                        ClmDiagnosisCode_1_Most_Frequent category
#                        ClmDiagnosisCode_2_Most_Frequent category
#                        ClmDiagnosisCode_3_Most_Frequent category
#                        AttendingPhysician_Most_Frequent category
#                        OperatingPhysician_Most_Frequent category
#                            OtherPhysician_Most_Frequent category
#                       Avg_allocated_Amount_Per_Provider  float64
#                    Avg_Deductible_Amt_Paid_Per_Provider  float64
#                 Avg_InscClaimAmtReimbursed_Per_Provider  float64
#                                     perc_allocated_used  float64
#                                          prv_avg_claims  float64
#                            prv_avg_claim_cost_indicator  float64
#                                prv_avg_claims_indicator  float64

# %%
print(df_train.shape)         # returns a (delayed) tuple, e.g. (n_rows, n_cols)
print(df_train.head(3))
# Out:
# (<dask_expr.expr.Scalar: expr=FromGraph(d7267b5).size() // 95, dtype=int64>, 95)
# [                                        ] | 0% Completed | 154.91 us
# [########################################] | 100% Completed | 108.11 ms
#    Provider  ClaimDuration_sum  ClaimDuration_mean  ClaimDuration_std  \
# 0  PRV52145              335.0            1.367347           4.708267
# 1  PRV55104               72.0            1.384615           4.822959
# 2  PRV54894             1024.0            4.471616           6.659338
#
#    ClaimDuration_max  ClaimDuration_min  HospitalDuration_sum  \
# 0               20.0                0.0                   0.0
# 1               20.0                0.0                   0.0
# 2               35.0                0.0                 918.0
#
#    HospitalDuration_mean  HospitalDuration_std  HospitalDuration_max  ...  \
# 0                    NaN                   NaN                   NaN  ...
# 1                    NaN                   NaN                   NaN  ...
# 2               6.652174              7.147714                  35.0  ...
#
#    AttendingPhysician_Most_Frequent  OperatingPhysician_Most_Frequent  \
# 0                         PHY373236                                 0
# 1                         PHY317949                                 0
# 2                         PHY424317                                 0
#
#    OtherPhysician_Most_Frequent  Avg_allocated_Amount_Per_Provider  \
# 0                             0                        5285.673469
# 1                             0                        8637.307692
# 2                             0                       17460.960699
#
#    Avg_Deductible_Amt_Paid_Per_Provider  \
# 0                            373.779592
# 1                            577.230769
# 2                           1191.240175
#
#    Avg_InscClaimAmtReimbursed_Per_Provider  perc_allocated_used  \
# 0                              4569.551020             0.854206
# 1                              6325.769231             0.713211
# 2                             16329.039301             0.930428
#
#    prv_avg_claims  prv_avg_claim_cost_indicator  prv_avg_claims_indicator
# 0        1.038136                 -4.196304e+04                  1.038136
# 1        1.130435                 -8.799304e+04                  1.130435
# 2        1.095694                  1.654187e+06                  1.095694
#
# [3 rows x 95 columns]

# %%
missing = df_train.isnull().sum().compute()
print(missing[missing > 0])
# Out:
# Series([], dtype: int64)

# %%
import dask.dataframe as dd
import pandas as pd
import numpy as np
from dask_ml.preprocessing import StandardScaler

class MedicarePreprocessor:
    def __init__(self, df: dd.DataFrame):
        self.df = df

        self.cat_cols = [
            "Provider",
            "Race_mode",
            "State_mode",
            "County_mode",
            "PotentialFraud",
            "ClmAdmitDiagnosisCode_Most_Frequent",
            "ClmDiagnosisCode_1_Most_Frequent",
            "ClmDiagnosisCode_2_Most_Frequent",
            "ClmDiagnosisCode_3_Most_Frequent",
            "AttendingPhysician_Most_Frequent",
            "OperatingPhysician_Most_Frequent",
            "OtherPhysician_Most_Frequent"
        ]

        self.num_cols = [
            col
            for col, dtype in df.dtypes.items()
            if (dtype == "float64" and col != "PotentialFraud")
        ]

        self.target_col = "PotentialFraud"

    def drop_unused_columns(self, drop_cols: list = None):
        if drop_cols is None:
            drop_cols = [
                "ClmAdmitDiagnosisCode_Most_Frequent",
                "ClmDiagnosisCode_2_Most_Frequent",
                "ClmDiagnosisCode_3_Most_Frequent",
                "AttendingPhysician_Most_Frequent"
            ]
        to_drop = [c for c in drop_cols if c in self.df.columns]
        if to_drop:
            self.df = self.df.drop(columns=to_drop)
        self.cat_cols = [c for c in self.cat_cols if c not in to_drop]
        return self

    def fill_missing(self):
        # 1) Compute all numeric means in one shot
        means = self.df[self.num_cols].mean().compute()  # pandas.Series of means
        means_dict = {col: float(means[col]) for col in self.num_cols}

        # 2) Cast cat columns to string, then fill all missing with "MISSING"
        for col in self.cat_cols:
            self.df[col] = self.df[col].astype("string")

        fill_dict = means_dict.copy()
        for col in self.cat_cols:
            fill_dict[col] = "MISSING"

        # 3) One fillna call for everything:
        self.df = self.df.fillna(fill_dict)
        return self

    def encode_categoricals(self):
        # 1) Cast all cat columns to category dtype
        for col in self.cat_cols:
            self.df[col] = self.df[col].astype("category")

        # 2) One global categorize/shuffle
        self.df = self.df.categorize(columns=self.cat_cols)

        # 3) One pass to convert each cat to codes
        def _apply_cat_codes(pdf):
            pdf2 = pdf.copy()
            for c in self.cat_cols:
                pdf2[c] = pdf2[c].cat.codes.astype("int64")
            return pdf2

        self.df = self.df.map_partitions(_apply_cat_codes)
        return self

    def clip_outliers(self, lower_quantile=0.01, upper_quantile=0.99):
        for col in self.num_cols:
            q_low = self.df[col].quantile(lower_quantile).compute()
            q_high = self.df[col].quantile(upper_quantile).compute()
            self.df[col] = self.df[col].clip(lower=q_low, upper=q_high)
        return self

    def feature_engineering(self):
        def _safe_divide_avg_cost(pdf):
            num = pdf["Provider_Insurance_Claim_Reimbursement_Amt"]
            den = pdf["TotalClaims"]
            return pd.Series(
                np.where(den == 0, 0.0, num / den),
                index=pdf.index,
                name="avg_cost_per_claim"
            )

        self.df["avg_cost_per_claim"] = self.df.map_partitions(_safe_divide_avg_cost)
        self.num_cols.append("avg_cost_per_claim")

        def _pct_chronic_alz(pdf):
            num = pdf["Provider_Total_ChronicCond_Alzheimer_Patients"]
            den = pdf["Provider_Total_Patients"]
            return pd.Series(
                np.where(den == 0, 0.0, num / den),
                index=pdf.index,
                name="perc_chronic_alz"
            )

        self.df["perc_chronic_alz"] = self.df.map_partitions(_pct_chronic_alz)
        self.num_cols.append("perc_chronic_alz")

        return self

    def scale_numeric_features(self):
        exclude = {self.target_col, "Provider"}
        to_scale = [c for c in self.num_cols if c not in exclude]

        if to_scale:
            scaler = StandardScaler()
            scaled_df = scaler.fit_transform(self.df[to_scale])
            self.df = dd.concat(
                [self.df.drop(columns=to_scale), scaled_df],
                axis=1
            )
        return self

    def get_processed_df(self) -> dd.DataFrame:
        self.df = self.df.persist()
        return self.df

# %%
# 2.3) Instantiate the preprocessor
preprocessor = MedicarePreprocessor(df_train)

# 2.4) Chain the preprocessing steps in order
df_train_processed = (
    preprocessor
      .drop_unused_columns()      # drop columns you don’t plan to use
      .fill_missing()             # impute numeric → mean, category → mode
      .encode_categoricals()      # convert each category to integer codes
      .feature_engineering()      # OPTIONAL: add new ratio features
      .scale_numeric_features()   # standard‐scale every numeric column
      .get_processed_df()         # persist & retrieve final Dask DataFrame
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.venv/lib64/python3.9/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ClmAdmitDiagnosisCode_Most_Frequent'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 6
#       2 preprocessor = MedicarePreprocessor(df_train)
#       4 # 2.4) Chain the preprocessing steps in order
#       5 df_train_processed = (
# ----> 6     preprocessor
#       7       .drop_unused_columns()      # drop columns you don’t plan to use
#       8       .fill_missing()             # impute numeric → mean, category → mode
#       9       .encode_categoricals()      # convert each category to integer codes
#      10       .feature_engineering()      # OPTIONAL: add new ratio features
#      11       .scale_numeric_features()   # standard‐scale every numeric column
#      12       .get_processed_df()         # persist & retrieve final Dask DataFrame
#      13 )
#
# Cell In[30], line 54, in MedicarePreprocessor.fill_missing(self)
#      52 # 2) Cast cat columns to string, then fill all missing with "MISSING"
#      53 for col in self.cat_cols:
# ---> 54     self.df[col] = self.df[col].astype("string")
#      56 fill_dict = means_dict.copy()
#      57 for col in self.cat_cols:
#
# File ~/.venv/lib64/python3.9/site-packages/dask_expr/_collection.py:413, in FrameBase.__getitem__(self, other)
#     411 elif isinstance(other, list):
#     412     other = other.copy()
# --> 413 return new_collection(self.expr.__getitem__(other))
#
# File ~/.venv/lib64/python3.9/site-packages/dask_expr/_collection.py:4794, in new_collection(expr)
#    4792 def new_collection(expr):
#    4793     """Create new collection from an expr"""
# -> 4794     meta = expr._meta
#    4795     expr._name  # Ensure backend is imported
#    4796     return get_collection_type(meta)(expr)
#
# File /usr/lib64/python3.9/functools.py:993, in cached_property.__get__(self, instance, owner)
#     991 val = cache.get(self.attrname, _NOT_FOUND)
#     992 if val is _NOT_FOUND:
# --> 993     val = self.func(instance)
#     994     try:
#     995         cache[self.attrname] = val
#
# File ~/.venv/lib64/python3.9/site-packages/dask_expr/_expr.py:2050, in Projection._meta(self)
#    2047 @functools.cached_property
#    2048 def _meta(self):
#    2049     if is_dataframe_like(self.frame._meta):
# -> 2050         return super()._meta
#    2051     # if we are not a DataFrame and have a scalar, we reduce to a scalar
#    2052     if not isinstance(self.operand("columns"), (list, slice)) and not hasattr(
#    2053         self.operand("columns"), "dtype"
#    2054     ):
#
# File /usr/lib64/python3.9/functools.py:993, in cached_property.__get__(self, instance, owner)
#     991 val = cache.get(self.attrname, _NOT_FOUND)
#     992 if val is _NOT_FOUND:
# --> 993     val = self.func(instance)
#     994     try:
#     995         cache[self.attrname] = val
#
# File ~/.venv/lib64/python3.9/site-packages/dask_expr/_expr.py:496, in Blockwise._meta(self)
#     493 @functools.cached_property
#     494 def _meta(self):
#     495     args = [op._meta if isinstance(op, Expr) else op for op in self._args]
# --> 496     return self.operation(*args, **self._kwargs)
#
# File ~/.venv/lib64/python3.9/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/.venv/lib64/python3.9/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'ClmAdmitDiagnosisCode_Most_Frequent'

# %%
print(df_train_processed.dtypes)
print(df_train_processed.head(3))
# Out:
# Provider                          int64
# Race_mode                         int64
# State_mode                        int64
# County_mode                       int64
# PotentialFraud                    int64
#                                  ...
# prv_avg_claims                  float64
# prv_avg_claim_cost_indicator    float64
# prv_avg_claims_indicator        float64
# avg_cost_per_claim              float64
# perc_chronic_alz                float64
# Length: 93, dtype: object
# [########################################] | 100% Completed | 102.01 ms
#    Provider  Race_mode  State_mode  County_mode  PotentialFraud  \
# 0       914          0           1            9               0
# 1      3273          0          26           16               0
# 2      3112          0          26           58               1
#
#    ClmDiagnosisCode_1_Most_Frequent  OperatingPhysician_Most_Frequent  \
# 0                               277                                 0
# 1                               277                                 0
# 2                                11                                 0
#
#    OtherPhysician_Most_Frequent  ClaimDuration_sum  ClaimDuration_mean  ...  \
# 0                             0           0.364006           -0.314280  ...
# 1                             0          -0.246895           -0.305887  ...
# 2                             0           1.964424            1.194455  ...
#
#    ClmDiagnosisCode_3_Count  Avg_allocated_Amount_Per_Provider  \
# 0                  0.509379                          -0.477602
# 1                 -0.177849                           0.042061
# 2                  1.116283                           1.410150
#
#    Avg_Deductible_Amt_Paid_Per_Provider  \
# 0                             -0.375682
# 1                              0.065578
# 2                              1.397284
#
#    Avg_InscClaimAmtReimbursed_Per_Provider  perc_allocated_used  \
# 0                                -0.423120             0.132287
# 1                                -0.133897            -0.713648
# 2                                 1.513495             0.589595
#
#    prv_avg_claims  prv_avg_claim_cost_indicator  prv_avg_claims_indicator  \
# 0       -0.539095                     -0.156164                 -0.539095
# 1       -0.366773                     -0.327462                 -0.366773
# 2       -0.431634                      6.155988                 -0.431634
#
#    avg_cost_per_claim  perc_chronic_alz
# 0           -0.428244         -0.487604
# 1           -0.417469          0.229200
# 2            1.702587          0.036966
#
# [3 rows x 93 columns]

# %%
def save_dask_to_s3(df, path, file_format="csv", single_file=False, index=False):
    """
    Save a Dask DataFrame to S3 in CSV or Parquet format.
    
    Parameters:
        df (dask.DataFrame): The Dask DataFrame to save
        path (str): S3 path (e.g. s3://bucket/folder/)
        file_format (str): 'csv' or 'parquet'
        single_file (bool): Save as single file (only for small data)
        index (bool): Whether to save the index
    """
    if file_format == "csv":
        if single_file:
            df.compute().to_csv(path, index=index)
        else:
            df.to_csv(path + "part-*.csv", index=index)
    elif file_format == "parquet":
        df.to_parquet(path, write_index=index)
    else:
        raise ValueError("Unsupported file_format: choose 'csv' or 'parquet'")

# %%
prosessed_path = "s3://medicare-fraud-data-25-05-2025/processed/"
# Save the merged DataFrames to S3
save_dask_to_s3(df_train_processed, prosessed_path + "train/")
#save_dask_to_s3(df_train_processed, prosessed_path + "test/")
# Out:
# [                                        ] | 0% Completed | 215.26 us
# [########################################] | 100% Completed | 1.21 sms

# %%
df_train_processed.head(3)
# Out:
#    Provider  Race_mode  State_mode  County_mode  PotentialFraud  \
# 0       914          0           1            9               0
# 1      3273          0          26           16               0
# 2      3112          0          26           58               1
#
#    ClmDiagnosisCode_1_Most_Frequent  OperatingPhysician_Most_Frequent  \
# 0                               277                                 0
# 1                               277                                 0
# 2                                11                                 0
#
#    OtherPhysician_Most_Frequent  ClaimDuration_sum  ClaimDuration_mean  ...  \
# 0                             0           0.364006           -0.314280  ...
# 1                             0          -0.246895           -0.305887  ...
# 2                             0           1.964424            1.194455  ...
#
#    ClmDiagnosisCode_3_Count  Avg_allocated_Amount_Per_Provider  \
# 0                  0.509379                          -0.477602
# 1                 -0.177849                           0.042061
# 2                  1.116283                           1.410150
#
#    Avg_Deductible_Amt_Paid_Per_Provider  \
# 0                             -0.375682
# 1                              0.065578
# 2                              1.397284
#
#    Avg_InscClaimAmtReimbursed_Per_Provider  perc_allocated_used  \
# 0                                -0.423120             0.132287
# 1                                -0.133897            -0.713648
# 2                                 1.513495             0.589595
#
#    prv_avg_claims  prv_avg_claim_cost_indicator  prv_avg_claims_indicator  \
# 0       -0.539095                     -0.156164                 -0.539095
# 1       -0.366773                     -0.327462                 -0.366773
# 2       -0.431634                      6.155988                 -0.431634
#
#    avg_cost_per_claim  perc_chronic_alz
# 0           -0.428244         -0.487604
# 1           -0.417469          0.229200
# 2            1.702587          0.036966
#
# [3 rows x 93 columns]

# %%
import fsspec

fs = fsspec.filesystem("s3")
fs.ls("medicare-fraud-data-25-05-2025/processed/train/")
# Out:
# ['medicare-fraud-data-25-05-2025/processed/train/part-0.csv',
#  'medicare-fraud-data-25-05-2025/processed/train/part-1.csv',
#  'medicare-fraud-data-25-05-2025/processed/train/part-2.csv']

# %%
# 1.1) Separate X and y
X = df_train_processed.drop(columns=["Provider", "PotentialFraud"])
y = df_train_processed["PotentialFraud"]

# 1.2) Optional: Persist X and y separately for downstream reuse
X = X.persist()
y = y.persist()
# Out:
# [########################################] | 100% Completed | 106.59 ms
# [########################################] | 100% Completed | 103.51 ms

# %%
import dask.dataframe as dd

# 1) Suppose df_train_processed has columns ["Provider", …, "PotentialFraud"].
#    We’ll split it into two subsets: non-fraud (0) and fraud (1).

df_zero = df_train_processed[df_train_processed.PotentialFraud == 0]
df_one  = df_train_processed[df_train_processed.PotentialFraud == 1]

# 2) For each subset, call `.random_split([0.8, 0.2], random_state=42)` 
#    to get an 80/20 split within that class.

#    Note: random_split returns a list [train_part, test_part].
train_zero, test_zero = df_zero.random_split([0.8, 0.2], random_state=42)
train_one,  test_one  = df_one.random_split([0.8, 0.2], random_state=42)

# 3) Concatenate the “zero” and “one” pieces to form overall train/test sets:
df_train = dd.concat([train_zero, train_one])
df_test  = dd.concat([test_zero,  test_one])

# 4) (Optional) Shuffle each combined DataFrame so the 0/1 examples are interleaved
df_train = df_train.shuffle(on="Provider", random_state=42)
df_test  = df_test.shuffle(on="Provider", random_state=42)

# 5) Finally, separate X_train/y_train and X_test/y_test:
X_train = df_train.drop(columns=["Provider", "PotentialFraud"])
y_train = df_train["PotentialFraud"]

X_test  = df_test.drop(columns=["Provider", "PotentialFraud"])
y_test  = df_test["PotentialFraud"]

# 6) Persist each:
X_train = X_train.persist()
y_train = y_train.persist()
X_test  = X_test.persist()
y_test  = y_test.persist()
# Out:
# [########################################] | 100% Completed | 205.57 ms
# [########################################] | 100% Completed | 205.55 ms
# [########################################] | 100% Completed | 207.77 ms
# [########################################] | 100% Completed | 205.97 ms

# %%
from dask.distributed import Client

# If you already have a scheduler address, you can pass it here. 
# Otherwise, this will start a local cluster with several threads/processes.
client = Client()
# Out:
# /home/ec2-user/.venv/lib64/python3.9/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 34649 instead
#   warnings.warn(
# 2025-06-06 16:34:03,126 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 2539a9672c51086375bc0f06d75d2f8c initialized by task ('shuffle-transfer-2539a9672c51086375bc0f06d75d2f8c', 1) executed on worker tcp://127.0.0.1:39019
# 2025-06-06 16:34:03,673 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 2539a9672c51086375bc0f06d75d2f8c deactivated due to stimulus 'task-finished-1749227643.670773'
# 2025-06-06 16:59:54,337 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle d7d50cbf6d487ca0deee37fa837e6626 initialized by task ('shuffle-transfer-d7d50cbf6d487ca0deee37fa837e6626', 5) executed on worker tcp://127.0.0.1:39019
# 2025-06-06 16:59:54,909 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle d7d50cbf6d487ca0deee37fa837e6626 deactivated due to stimulus 'task-finished-1749229194.904566'
# 2025-06-06 17:00:29,918 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 1b41d3a3349ac5e511260ae0200f02a2 initialized by task ('shuffle-transfer-1b41d3a3349ac5e511260ae0200f02a2', 5) executed on worker tcp://127.0.0.1:39019
# 2025-06-06 17:00:30,585 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 1b41d3a3349ac5e511260ae0200f02a2 deactivated due to stimulus 'task-finished-1749229230.577175'

# %%
pip install xgboost[dask]
# Out:
# Requirement already satisfied: xgboost[dask] in /home/ec2-user/.venv/lib/python3.9/site-packages (2.1.4)
# Requirement already satisfied: numpy in /home/ec2-user/.venv/lib/python3.9/site-packages (from xgboost[dask]) (2.0.2)
# Requirement already satisfied: nvidia-nccl-cu12 in /home/ec2-user/.venv/lib/python3.9/site-packages (from xgboost[dask]) (2.27.3)
# Requirement already satisfied: scipy in /home/ec2-user/.venv/lib/python3.9/site-packages (from xgboost[dask]) (1.13.1)
# Requirement already satisfied: dask in /home/ec2-user/.venv/lib/python3.9/site-packages (from xgboost[dask]) (2024.8.0)
# Requirement already satisfied: distributed in /home/ec2-user/.venv/lib/python3.9/site-packages (from xgboost[dask]) (2024.8.0)
# Requirement already satisfied: pandas in /home/ec2-user/.venv/lib/python3.9/site-packages (from xgboost[dask]) (2.2.3)
# Requirement already satisfied: click>=8.1 in /home/ec2-user/.venv/lib/python3.9/site-packages (from dask->xgboost[dask]) (8.1.8)
# Requirement already satisfied: cloudpickle>=1.5.0 in /home/ec2-user/.venv/lib/python3.9/site-packages (from dask->xgboost[dask]) (3.1.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /home/ec2-user/.venv/lib/python3.9/site-packages (from dask->xgboost[dask]) (2025.5.1)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/.venv/lib/python3.9/site-packages (from dask->xgboost[dask]) (25.0)
# Requirement already satisfied: partd>=1.4.0 in /home/ec2-user/.venv/lib/python3.9/site-packages (from dask->xgboost[dask]) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /home/ec2-user/.venv/lib/python3.9/site-packages (from dask->xgboost[dask]) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in /home/ec2-user/.venv/lib/python3.9/site-packages (from dask->xgboost[dask]) (1.0.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /home/ec2-user/.venv/lib/python3.9/site-packages (from dask->xgboost[dask]) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /home/ec2-user/.venv/lib/python3.9/site-packages (from importlib-metadata>=4.13.0->dask->xgboost[dask]) (3.22.0)
# Requirement already satisfied: locket in /home/ec2-user/.venv/lib/python3.9/site-packages (from partd>=1.4.0->dask->xgboost[dask]) (1.0.0)
# Requirement already satisfied: jinja2>=2.10.3 in /home/ec2-user/.venv/lib/python3.9/site-packages (from distributed->xgboost[dask]) (3.1.6)
# Requirement already satisfied: msgpack>=1.0.0 in /home/ec2-user/.venv/lib/python3.9/site-packages (from distributed->xgboost[dask]) (1.1.0)
# Requirement already satisfied: psutil>=5.7.2 in /home/ec2-user/.venv/lib/python3.9/site-packages (from distributed->xgboost[dask]) (7.0.0)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /home/ec2-user/.venv/lib/python3.9/site-packages (from distributed->xgboost[dask]) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /home/ec2-user/.venv/lib/python3.9/site-packages (from distributed->xgboost[dask]) (3.1.0)
# Requirement already satisfied: tornado>=6.0.4 in /home/ec2-user/.venv/lib/python3.9/site-packages (from distributed->xgboost[dask]) (6.5.1)
# Requirement already satisfied: urllib3>=1.24.3 in /home/ec2-user/.venv/lib/python3.9/site-packages (from distributed->xgboost[dask]) (1.26.20)
# Requirement already satisfied: zict>=3.0.0 in /home/ec2-user/.venv/lib/python3.9/site-packages (from distributed->xgboost[dask]) (3.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ec2-user/.venv/lib/python3.9/site-packages (from jinja2>=2.10.3->distributed->xgboost[dask]) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/ec2-user/.venv/lib/python3.9/site-packages (from pandas->xgboost[dask]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/ec2-user/.venv/lib/python3.9/site-packages (from pandas->xgboost[dask]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/ec2-user/.venv/lib/python3.9/site-packages (from pandas->xgboost[dask]) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/.venv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->xgboost[dask]) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import xgboost as xgb

# 3.2.1) Create DaskDMatrix for train and test
dtrain = xgb.dask.DaskDMatrix(client, X_train, y_train)
dtest  = xgb.dask.DaskDMatrix(client, X_test, y_test)

# %%
# Count negatives and positives in the training set
neg_count = (y_train == 0).sum().compute()
pos_count = (y_train == 1).sum().compute()

scale_pos_weight = neg_count / pos_count

# %%
params = {
    "objective": "binary:logistic",
    "eval_metric": "auc",            # area under ROC
    "tree_method": "hist",           # “hist” is faster on large data
    "scale_pos_weight": scale_pos_weight,
    "learning_rate": 0.1,            # you can tune this later
    "max_depth": 5,                  # also tunable
    "subsample": 0.8,
    "colsample_bytree": 0.8
}
num_boost_round = 100

# %%
output = xgb.dask.train(
    client,
    params,
    dtrain,
    num_boost_round=num_boost_round,
    evals=[(dtest, "validation")],
    verbose_eval=False
)
bst = output["booster"]   # the trained Booster object
history = output["history"]  # dictionary of evaluation metrics
# Out:
# [16:33:43] Task [xgboost.dask-0]:tcp://127.0.0.1:36239 got rank 0
# [16:33:43] Task [xgboost.dask-1]:tcp://127.0.0.1:39019 got rank 1

# %%
import optuna
from xgboost import dask as dxgb
