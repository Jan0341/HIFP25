# %%
import dask.dataframe as dd
from dask.diagnostics import ProgressBar
pbar = ProgressBar(); pbar.register()

# %%
# Pfade
processed_path = "s3://medicare-fraud-data-25-05-2025/processed/train/*.csv"

# Lade trainierten Datensatz (Parquet empfohlen für S3)
df_train = dd.read_csv(processed_path)

# %%
df_train.head(20)
# Out:
# [########################################] | 100% Completed | 101.71 ms
#     Provider  Race_mode  State_mode  County_mode  PotentialFraud  \
# 0        914          0           1            9               0
# 1       3273          0          26           16               0
# 2       3112          0          26           58               1
# 3       3137          0          26           16               0
# 4       3363          0          27            2               1
# 5       3157          0          26           16               1
# 6       5043          0          43           10               1
# 7       5058          0          43           10               0
# 8       1681          0           8          134               0
# 9       4014          0          50            2               0
# 10      3973          0          32           96               0
# 11      3808          0          30          184               0
# ...
